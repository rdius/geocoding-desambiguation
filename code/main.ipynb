# %%
from ipynb.fs.full.geocoder import desambiguation as ds

# %%
file = '../candidates/AllSneCandidate.json'

# %%
Alldf = ds(file)
# Out:
# *** Study_suggests_%27sleeping_sickness%27_parasite_mutated_to_evade_immune_system_defences
# No match for SNE in : ['Democratic Republic of Congo']
#
#
# $$$$$1 NonAmbCc {'South Sudan': ('South Sudan', '7.5', '30', 'SS', 'A', 8260490)}
# No match for SNE in : ['Democratic Republic of Congo']
#
#
# No match for SNE in : ['Democratic Republic of Congo']
#
#
# No match for SNE in : ['Democratic Republic of Congo']
#
#
# No match for SNE in : ['Democratic Republic of Congo']
#
#
# No match for SNE in : ['Democratic Republic of Congo']
#
#
# debugging Democratic Republic of Congo
# Democratic Republic of Congo [('DR Congo', 86)]
# $$$$$$ NotAsSne dict_keys([])
#
# ********Non-Ambiguous********
#
# South Sudan : ('South Sudan', '7.5', '30', 'SS', 'A', 8260490)
# Democratic Republic of Congo : ['DR Congo', '-2.5', '23.5', 'CD', 'A', 84068091]
#
#
# ********Ambiguous********
#
# Georgia : 2 Candidates found
# Angola : 6 Candidates found
# Uganda : 2 Candidates found
# ...

# %%
Alldf.to_csv('../geocoded/Geovidata_geocod_dsamb.csv')
